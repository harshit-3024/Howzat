# %% [markdown]
# # 2008-2011

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("ipl_da_08_11.csv")

# %%
data
# Out:
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0   Match Type  \
# 0               0             0             0           0       League
# 1               1             1             1           1       League
# 2               2             2             2           2       League
# 3               3             3             3           3       League
# 4               4             4             4           4       League
# ..            ...           ...           ...         ...          ...
# 273           273           273           273         273       League
# 274           274           274           274         274  Qualifier 1
# 275           275           275           275         275   Eliminator
# 276           276           276           276         276  Qualifier 2
# 277           277           277           277         277        Final
#
#                     POTM       Venue                        Team1  \
# ...

# %%
data[data.isna().any(axis=1)==1]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.3, Unnamed: 0.2, Unnamed: 0.1, Unnamed: 0, Match Type, POTM, Venue, Team1, Team2, Toss_Winner, Toss_Decision, Winner, Win_Margin, Result_Type, Target_Runs, Match, Season]
# Index: []

# %%
data=data.dropna()

# %%
data.columns
# Out:
# Index(['Unnamed: 0.3', 'Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0',
#        'Match Type', 'POTM', 'Venue', 'Team1', 'Team2', 'Toss_Winner',
#        'Toss_Decision', 'Winner', 'Win_Margin', 'Result_Type', 'Target_Runs',
#        'Match', 'Season'],
#       dtype='object')

# %%
data.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278 entries, 0 to 277
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0.3   278 non-null    int64
#  1   Unnamed: 0.2   278 non-null    int64
#  2   Unnamed: 0.1   278 non-null    int64
#  3   Match Type     278 non-null    object
#  4   POTM           278 non-null    object
#  5   Venue          278 non-null    object
#  6   Team1          278 non-null    object
#  7   Team2          278 non-null    object
#  8   Toss_Winner    278 non-null    object
#  9   Toss_Decision  278 non-null    object
#  10  Winner         278 non-null    object
#  11  Win_Margin     278 non-null    object
#  12  Result_Type    278 non-null    object
#  13  Target_Runs    278 non-null    int64
#  14  Match          278 non-null    int64
#  15  Season         278 non-null    int64
# dtypes: int64(6), object(10)
# memory usage: 34.9+ KB

# %%
data.Match.value_counts()
# Out:
# Match
# 1     4
# 2     4
# 3     4
# 4     4
# 5     4
#      ..
# 70    3
# 71    3
# 72    2
# 73    2
# 74    1
# Name: count, Length: 74, dtype: int64

# %%
season = [2011]
m_type = ["Qualifier 1", "Eliminator", "Qualifier 2", "Final"]

# %%
data[data.Match=="Final"]
season_1=[2008,2009,2010]
ses_8_9=["SemiFinal_1","SemiFinal_2","Final"]
M_type=ses_8_9 + m_type

# %%
data
# Out:
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1   Match Type  \
# 0               0             0             0       League
# 1               1             1             1       League
# 2               2             2             2       League
# 3               3             3             3       League
# 4               4             4             4       League
# ..            ...           ...           ...          ...
# 273           273           273           273       League
# 274           274           274           274  Qualifier 1
# 275           275           275           275   Eliminator
# 276           276           276           276  Qualifier 2
# 277           277           277           277        Final
#
#                     POTM       Venue                        Team1  \
# 0          Harshal Patel     Chennai               Mumbai Indians
# 1         Shikhar Dhawan    Wankhede          Chennai Super Kings
# ...

# %%
data[data.Match=="Final"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.3, Unnamed: 0.2, Unnamed: 0.1, Match Type, POTM, Venue, Team1, Team2, Toss_Winner, Toss_Decision, Winner, Win_Margin, Result_Type, Target_Runs, Match, Season]
# Index: []

# %%
for ses in season_1:
  i=0
  m_idx=data.loc[(data["Season"]==ses)&(data["Match"].str.contains("Final"))].index
  for idx in m_idx:
    if i < len(ses_8_9):
            data.at[idx, "Match"] = ses_8_9[i]
            i += 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 3
#       1 for ses in season_1:
#       2   i=0
# ----> 3   m_idx=data.loc[(data["Season"]==ses)&(data["Match"].str.contains("Final"))].index
#       4   for idx in m_idx:
#       5     if i < len(ses_8_9):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
# ...

# %%
for ses in season:
  i=0
  m_idx=data.loc[(data["Season"]==ses)&(data["Match"].str.contains("Final"))].index
  for idx in m_idx:
    if i < len(m_type):
            data.at[idx, "Match"] = m_type[i]
            i += 1

# %%
data.drop("index",axis=1,inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11236\662639610.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop("index",axis=1,inplace=True)

# %%
data
# Out:
#     Match Type              POTM         Venue Team1 Team2  \
# 0       League  Brendon McCullum     Bengaluru   KKR   RCB
# 1       League    Michael Hussey        Mohali   CSK  KXIP
# 2       League  Farveez Maharoof         Delhi    RR    DC
# 3       League      David Hussey  Eden Gardens   DCH   KKR
# 4       League      Mark Boucher      Wankhede    MI   RCB
# ..         ...               ...           ...   ...   ...
# 247     League    James Franklin  Eden Gardens   KKR    MI
# 248      Final      Suresh Raina      Wankhede   RCB   CSK
# 249      Final       Munaf Patel      Wankhede   KKR    MI
# 250      Final       Chris Gayle       Chennai   RCB    MI
# 251      Final      Murali Vijay       Chennai   CSK   RCB
#
#                      Toss_Winner Toss_Decision      Winner  Win_Margin  \
# 0    Royal Challengers Bangalore         field         KKR       140.0
# 1            Chennai Super Kings           bat         CSK        33.0
# ...

# %%
for j in M_type:
  data.loc[data["Match"].str.contains(j,na=False),"Match Type"]=j

# %%
data
# Out:
#       Match Type              POTM         Venue Team1 Team2  \
# 0         League  Brendon McCullum     Bengaluru   KKR   RCB
# 1         League    Michael Hussey        Mohali   CSK  KXIP
# 2         League  Farveez Maharoof         Delhi    RR    DC
# 3         League      David Hussey  Eden Gardens   DCH   KKR
# 4         League      Mark Boucher      Wankhede    MI   RCB
# ..           ...               ...           ...   ...   ...
# 247       League    James Franklin  Eden Gardens   KKR    MI
# 248  Qualifier 1      Suresh Raina      Wankhede   RCB   CSK
# 249   Eliminator       Munaf Patel      Wankhede   KKR    MI
# 250  Qualifier 2       Chris Gayle       Chennai   RCB    MI
# 251        Final      Murali Vijay       Chennai   CSK   RCB
#
#                      Toss_Winner Toss_Decision      Winner  Win_Margin  \
# 0    Royal Challengers Bangalore         field         KKR       140.0
# 1            Chennai Super Kings           bat         CSK        33.0
# ...

# %%
data["Target_Runs"]=data["Target_Runs"].astype("int")
data["Win_Margin"]=data["Win_Margin"].astype("int")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 245 entries, 0 to 251
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Match Type     245 non-null    object
#  1   POTM           245 non-null    object
#  2   Venue          245 non-null    object
#  3   Team1          245 non-null    object
#  4   Team2          245 non-null    object
#  5   Toss_Winner    245 non-null    object
#  6   Toss_Decision  245 non-null    object
#  7   Winner         245 non-null    object
#  8   Win_Margin     245 non-null    int64
#  9   Result_Type    245 non-null    object
#  10  Target_Runs    245 non-null    int64
#  11  Season         245 non-null    int64
#  12  Match          245 non-null    object
# dtypes: int64(3), object(10)
# memory usage: 34.9+ KB
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11236\3397499786.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data.to_csv("ipl_da_08_11.csv")

# %% [markdown]
# # 2012-2015

# %%
data.isna().sum()
# Out:
# Match Type       0
# POTM             0
# Venue            0
# Team1            0
# Team2            0
# Toss_Winner      0
# Toss_Decision    0
# Winner           0
# Win_Margin       0
# Result_Type      0
# Target_Runs      0
# Season           0
# Match            0
# dtype: int64

# %%
m_type=data["Match Type"].unique()
m_type=np.delete(m_type,0)
m_type
# Out:
# array(['Final', 'Qualifier 1', 'Eliminator', 'Qualifier 2'], dtype=object)

# %%
data=pd.read_csv("2012-2015.csv")
data.sample(2)
# Out:
#     Match Type            POTM                             Venue  \
# 160     League   Glenn Maxwell           Sharjah Cricket Stadium
# 131     League  Gautam Gambhir  Subrata Roy Sahara Stadium, Pune
#
#                      Team1                Team2            Toss_Winner  \
# 160        Kings XI Punjab  Sunrisers Hyderabad    Sunrisers Hyderabad
# 131  Kolkata Knight Riders        Pune Warriors  Kolkata Knight Riders
#
#     Toss_Decision     Winner Win_Margin Result_Type Target_Runs  Match  Season
# 160   Field first  Kings XI     72 runs        Runs         194      9    2014
# 131     Bat first       KKR     46 runs        Runs         153     56    2013

# %%
data["Win_Margin"]=data["Win_Margin"].str.split().str[0]

# %%
data
# Out:
#       Match Type                  POTM  \
# 0         League          Richard Levi
# 1         League          Irfan Pathan
# 2         League          Steven Smith
# 3         League        Ajinkya Rahane
# 4         League        AB de Villiers
# ..           ...                   ...
# 267       League  Mitchell McClenaghan
# 268  Qualifier 1        Kieron Pollard
# 269   Eliminator        AB de Villiers
# 270  Qualifier 2          Ashish Nehra
# 271        Final          Rohit Sharma
#
#                                                  Venue  \
# 0             MA Chidambaram Stadium, Chepauk, Chennai
# 1                                Eden Gardens, Kolkata
# 2                             Wankhede Stadium, Mumbai
# 3                       Sawai Mansingh Stadium, Jaipur
# 4                     M Chinnaswamy Stadium, Bangalore
# ..                                                 ...
# 267  Rajiv Gandhi International Stadium, Uppal, Hyd...
# ...

# %%
match_count = 0

for i in range(data.shape[0]): 
    for j in m_type: 
        if j in str(data.iloc[i]["Match Type"]): 
            match_count += 1

print("Total Matches Found:", match_count)
# Out:
# Total Matches Found: 16

# %% [markdown]
# # 2016 - 2020

# %%
data=pd.read_csv("data_2016-2020.csv")

# %%
data.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'Match Type', 'POTM',
#        'Venue', 'Team1', 'Team2', 'Toss_Winner', 'Toss_Decision', 'Winner',
#        'Win_Margin', 'Result_Type', 'Target_Runs', 'Match', 'Season'],
#       dtype='object')

# %%
data
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0   Match Type                 POTM  \
# 0               0             0           0       League        Harshal Patel
# 1               1             1           1       League       Shikhar Dhawan
# 2               2             2           2       League          Nitish Rana
# 3               3             3           3       League         Sanju Samson
# 4               4             4           4       League         Rahul Chahar
# ..            ...           ...         ...          ...                  ...
# 273           273           273         273       League      Abhishek Sharma
# 274           274           274         274  Qualifier 1       Mitchell Starc
# 275           275           275         275   Eliminator  Ravichandran Ashwin
# 276           276           276         276  Qualifier 2        Shahbaz Ahmed
# 277           277           277         277        Final       Mitchell Starc
#
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0.2     0
# Unnamed: 0.1     0
# Unnamed: 0       0
# Match Type       0
# POTM             0
# Venue            0
# Team1            0
# Team2            0
# Toss_Winner      0
# Toss_Decision    0
# Winner           0
# Win_Margin       0
# Result_Type      0
# Target_Runs      0
# Match            0
# Season           0
# dtype: int64

# %%
data[data.isnull().any(axis=1)==1]
# Out:
#      Unnamed: 0  index Match Type             POTM         Venue Team1 Team2  \
# 88           88     28        NaN              NaN           NaN   NaN   NaN
# 94           94     34     League    Krunal Pandya        Rajkot    GL    MI
# 189         189      9     League     Prithvi Shaw         Delhi   KKR    DC
# 228         228     48        NaN              NaN           NaN   NaN   NaN
# 230         230     50     League   Jasprit Bumrah      Wankhede    MI   SRH
# 241         241      1     League   Marcus Stoinis  Dubai (DICS)    DC  KXIP
# 249         249      9     League   AB de Villiers  Dubai (DICS)   RCB    MI
# 274         274     34     League  Lockie Ferguson     Abu Dhabi   KKR   SRH
#
#              Toss_Winner Toss_Decision Winner  Win_Margin Result_Type  \
# 88                   NaN           NaN    NaN         NaN         NaN
# 94         Gujarat Lions           bat  Match         NaN        runs
# ...

# %%
data.loc[228, 'Match Type'] = "League"
data.loc[228, 'POTM'] = "Andre Russell"
data.loc[228, 'Venue'] = "Eden Gardens"
data.loc[228, 'Team1'] = "KKR"
data.loc[228, 'Team2'] = "MI"
data.loc[228, 'Toss_Winner'] = "MI"
data.loc[228, 'Toss_Decision'] = "Field"
data.loc[228, 'Winner'] = "KKR"
data.loc[228, 'Win_Margin'] = 34
data.loc[228, 'Result_Type'] = "Runs"
data.loc[228, 'Target_Runs'] = 233
data.loc[228, 'Season'] = 2019
data.loc[228, 'Match'] = "47th Match"

data.loc[88, 'Match Type'] = "League"
data.loc[88, 'POTM'] = "Nathan Coulter-Nile"
data.loc[88, 'Venue'] = "Eden Gardens"
data.loc[88, 'Team1'] = "KKR"
data.loc[88, 'Team2'] = "RCB"
data.loc[88, 'Toss_Winner'] = "RCB"
data.loc[88, 'Toss_Decision'] = "Field"
data.loc[88, 'Winner'] = "KKR"
data.loc[88, 'Win_Margin'] = 82
data.loc[88, 'Result_Type'] = "Runs"
data.loc[88, 'Target_Runs'] = 132
data.loc[88, 'Season'] = 2017
data.loc[88, 'Match'] = "27th Match"

# %%
data.loc[94,"Win_Margin"]=0
data.loc[94,"Target_Runs"]=153
data.loc[94,"Winner"]="MI"

data.loc[189,"Win_Margin"]=0
data.loc[189,"Target_Runs"]=185
data.loc[189,"Winner"]="DC"

data.loc[230,"Win_Margin"]=0
data.loc[230,"Target_Runs"]=162
data.loc[230,"Winner"]="MI"

data.loc[241,"Win_Margin"]=0
data.loc[241,"Target_Runs"]=157
data.loc[241,"Winner"]="DC"

data.loc[249,"Win_Margin"]=0
data.loc[249,"Target_Runs"]=201
data.loc[249,"Winner"]="RCB"

data.loc[274,"Win_Margin"]=0
data.loc[274,"Target_Runs"]=1
data.loc[274,"Winner"]="KKR"

# %%
data.isnull().sum()
# Out:
# Unnamed: 0       0
# index            0
# Match Type       0
# POTM             0
# Venue            0
# Team1            0
# Team2            0
# Toss_Winner      0
# Toss_Decision    0
# Winner           0
# Win_Margin       0
# Result_Type      0
# Target_Runs      0
# Season           0
# Match            0
# dtype: int64

# %%
data
# Out:
#      Unnamed: 0  index   Match Type             POTM         Venue Team1  \
# 0             0      0       League   Ajinkya Rahane      Wankhede    MI
# 1             1      1       League    Andre Russell  Eden Gardens    DC
# 2             2      2       League      Aaron Finch        Mohali  KXIP
# 3             3      3       League   AB de Villiers     Bengaluru   RCB
# 4             4      4       League     Rohit Sharma  Eden Gardens   KKR
# ..          ...    ...          ...              ...           ...   ...
# 295         295     55       League   Shahbaz Nadeem       Sharjah    MI
# 296         296     56  Qualifier 1   Jasprit Bumrah  Dubai (DICS)    MI
# 297         297     57   Eliminator  Kane Williamson     Abu Dhabi   RCB
# 298         298     58  Qualifier 2   Marcus Stoinis     Abu Dhabi    DC
# 299         299     59        Final      Trent Boult  Dubai (DICS)    DC
#
#     Team2            Toss_Winner Toss_Decision       Winner  Win_Margin  \
# ...

# %%
data
# Out:
#       Match Type             POTM         Venue Team1 Team2  \
# 0         League   Ajinkya Rahane      Wankhede    MI   RPS
# 1         League    Andre Russell  Eden Gardens    DC   KKR
# 2         League      Aaron Finch        Mohali  KXIP    GL
# 3         League   AB de Villiers     Bengaluru   RCB   SRH
# 4         League     Rohit Sharma  Eden Gardens   KKR    MI
# ..           ...              ...           ...   ...   ...
# 295       League   Shahbaz Nadeem       Sharjah    MI   SRH
# 296  Qualifier 1   Jasprit Bumrah  Dubai (DICS)    MI    DC
# 297   Eliminator  Kane Williamson     Abu Dhabi   RCB   SRH
# 298  Qualifier 2   Marcus Stoinis     Abu Dhabi    DC   SRH
# 299        Final      Trent Boult  Dubai (DICS)    DC    MI
#
#                Toss_Winner Toss_Decision       Winner  Win_Margin Result_Type  \
# 0           Mumbai Indians           bat  Supergiants         9.0      wicket
# 1    Kolkata Knight Riders         field          KKR         9.0      wicket
# ...

# %%
match_count = 0

for i in range(data.shape[0]): 
    for j in m_type: 
        if j in str(data.iloc[i]["Match Type"]): 
            match_count += 1

print("Total Matches Found:", match_count)
# Out:
# Total Matches Found: 20

# %%
data.to_csv("data_2016-2020.csv")

# %% [markdown]
# # Data Cleaning on 2021-2024

# %%
data=pd.read_csv(r"C:\Users\Lenovo\OneDrive\Desktop\DATASCIENCE\Howzat\Season_2021-2024.csv")

# %%
data
# Out:
#      Unnamed: 0.1  Unnamed: 0   Match Type                 POTM       Venue  \
# 0               0           0       League        Harshal Patel     Chennai
# 1               1           1       League       Shikhar Dhawan    Wankhede
# 2               2           2       League          Nitish Rana     Chennai
# 3               3           3       League         Sanju Samson    Wankhede
# 4               4           4       League         Rahul Chahar     Chennai
# ..            ...         ...          ...                  ...         ...
# 273           273         273       League      Abhishek Sharma   Hyderabad
# 274           274         274  Qualifier 1       Mitchell Starc   Ahmedabad
# 275           275         275   Eliminator  Ravichandran Ashwin   Ahmedabad
# 276           276         276  Qualifier 2        Shahbaz Ahmed     Chennai
# 277           277         277        Final       Mitchell Starc     Chennai
#
# ...

# %%
data['Match Type'] = data['Match Type'].str.replace(' \(N\)', '', regex=True)
data
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\('
# <>:1: SyntaxWarning: invalid escape sequence '\('
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11236\2823977458.py:1: SyntaxWarning: invalid escape sequence '\('
#   data['Match Type'] = data['Match Type'].str.replace(' \(N\)', '', regex=True)
#      Unnamed: 0   Match Type                 POTM       Venue  \
# 0             0       League        Harshal Patel     Chennai
# 1             1       League       Shikhar Dhawan    Wankhede
# 2             2       League          Nitish Rana     Chennai
# 3             3       League         Sanju Samson    Wankhede
# 4             4       League         Rahul Chahar     Chennai
# ..          ...          ...                  ...         ...
# 273         273       League      Abhishek Sharma   Hyderabad
# 274         274  Qualifier 1       Mitchell Starc   Ahmedabad
# 275         275   Eliminator  Ravichandran Ashwin   Ahmedabad
# ...

# %%
match_count = 0

for i in range(data.shape[0]): 
    for j in m_type: 
        if j in str(data.iloc[i]["Match Type"]): 
            match_count += 1

print("Total Matches Found:", match_count)
# Out:
# Total Matches Found: 16

# %%
data.to_csv("Season_2021-2024.csv")
